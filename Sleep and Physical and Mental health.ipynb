# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt 
import pandas as pd
import numpy as np

# %%
# Set the API base URL
#url = "https://api.openweathermap.org/data/2.5/weather?"
#api_key = "appid=" + weather_api_key + "&units=metric&q="

# %%
sleep_df = pd.read_csv("Marqueze et al.csv")

# %%
sleep_df
# Out:
#           id  Gender   Age  Satlazer  Countrycat  Workhourtotal1cat  \
# 0          1       1  33.0         1           0                0.0
# 1          2       1  64.0         0           0                1.0
# 2          3       1  39.0         0           0                1.0
# 3          4       1  36.0         0           0                1.0
# 4          5       1  22.0         0           0                1.0
# ...      ...     ...   ...       ...         ...                ...
# 1756  580289       1  43.0         0           1                0.0
# 1757  580343       0  27.0         0           1                0.0
# 1758  580345       1  43.0         1           1                0.0
# 1759  580350       1  40.0         0           1                0.0
# 1760  580352       1  41.0         0           1                1.0
#
#       Enoughsleepcat  Educationlevel  Satworkhour2  SleepQualitycat  ...  \
# 0                0.0             2.0             1              0.0  ...
# ...

# %%
sleep_df.columns
# Out:
# Index(['id', 'Gender', 'Age', 'Satlazer', 'Countrycat', 'Workhourtotal1cat',
#        'Enoughsleepcat', 'Educationlevel', 'Satworkhour2', 'SleepQualitycat',
#        'AwakeningProblemscat', 'Sleepinesscat', 'Bedtimew', 'Uptimew',
#        'Bedtimef', 'Uptimef', 'Midsleepfreemean', 'Painneck_lowback',
#        'Work5cat', 'Depression', 'Country_Occup_Work5', 'Sunworkmonth_H',
#        'Sunfreemonth_H', 'SUNWORKFREEMONTH_HOUR', 'Occup_Work5', 'Work3cat2',
#        'SUNWORKMONTH_HOUR_Mean_INV', 'SUNWORKMONTH_HOUR_Median_INV'],
#       dtype='object')

# %%
sleep_brazil_df =

# %%
sleep_sweden_df =

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/94/mpb7fm5d4cn3zw60j1p1864m0000gn/T/ipykernel_6119/485406477.py in <module>
# ----> 1 for hour in sleep.df["Uptimew"]:
#       2     time_slept = sleep.df["Uptimew"]-sleep.df["Bedtimew"]
#       3
#
# NameError: name 'sleep' is not defined

# %%
time_sleptw = sleep_df["Uptimew"]-sleep_df["Bedtimew"]
print(time_sleptw)
# Out:
# 0       5.67
# 1       6.67
# 2       8.00
# 3       8.00
# 4       7.50
#         ...
# 1756    6.00
# 1757    6.67
# 1758    7.50
# 1759    8.00
# 1760    3.50
# Length: 1761, dtype: float64

# %%
time_sleptf = sleep_df["Uptimef"]-sleep_df["Bedtimef"]
time_sleptf
# Out:
# 0        9.67
# 1        8.67
# 2        8.00
# 3       10.50
# 4        9.50
#         ...
# 1756     8.00
# 1757    10.00
# 1758     9.50
# 1759     6.00
# 1760     4.75
# Length: 1761, dtype: float64

# %%
sleep_df["Time Slept w/ Work"]= time_sleptw

# %%
sleep_df.plot(kind="scatter", x="Age", y="Time Slept w/ Work", grid=True, figsize=(8,8),
              title="Age vs sleep")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
sleep_df.plot(kind="bar", x="Depression", y="Time Slept w/ Work")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
